# %%
def ques_11():
    P_FL = 3 ##kw
    V = 210 ##V
    Ra = 0.8 ##ohms
    Rsh = 90 ##ohms
    I0 = 7 ##A no load
    rpm = 1024 ##rpm

    Ifl = P_FL /V
    Ish = V/Rsh
    Ia = I0-Ish
    Pin = V*I0
    Ploss = Ia**2 * Ra + Ish**2 * Rsh
    Ptls = Pin - Ploss
    return print("Q-11 -->The Total Rotational Loss of the machine is ",Ptls," W")

ques_11()

def ques_12():
    rpm = 1230 ##rpm
    V = 230 ##v
    Vnew = 170 ##v
    Rpm = rpm
    return print("Q-12 -->The new rpm is ",Rpm," rpm")
ques_12()

def ques_13():
       rpm = 1390 ##rpm
       Pde = 11 ##kW
       V = 205 ##V
       Pdr = 3 ##kw
       Ra = 0.47 ##ohms
       Rf = 56 ##ohms

       Pin = Pdr
       I = Pde*10**3/V
       If = V/Rf
       Ia = If+I
       Eg = Ia*Ra +V
       I = Pin*10**3/V
       Ia = -I + If
       Eb = Ia*Ra +V
       Rpm = rpm*Eb/Eg
       return print("Q-13 -->The rpm is ",Rpm," rpm")
ques_13()

def ques_14():
    
    V = 230 ##V
    Pw = 10 ##kw
    rpm =820 ##rpm
    Ra = 0.029 ##ohms
    T = 60 ##Nm
    Ia = (V - (V**2 - 4*T*2*3.14*rpm/60*Ra)**0.5)/2/Ra
    return print("Q-14 -->The Current is ",Ia," A")
ques_14()

def ques_15():
    Pde = 39 ##kW
    Vo = 340 ##v
    rpm = 846 ##rpm
    Ra = 0.46 ##ohms
    Rf = 60 ##ohms
    Pin = 35 ##kw
    Vi = 320 ##v

    Il = Pde/Vo*10**3
    If = Vo/Rf
    Ia = If+Il
    Eg = Vo + Ia*Ra + 2
    Il = Pin*10**3/Vi
    Ia = Il- If
    Eb = Vo - Ia*Ra - 2
    Rpm = rpm*Eb/Eg
    return print("Q-15 -->The RPM is ",Rpm," rpm")
ques_15()


def ques_16():
    A =2
    Pw = 37 ##kw
    V = 420 ##V
    P = 6  ##POLES
    Z = 732 ##conductors
    Comm = 105 ##commutator segments
    Eff = 0.76 ##not percent
    If = 1 ##A
    Sh = 1.25 ##segments
    thetam = 360/Comm * Sh
    Pin = Pw/Eff
    Il = Pin*10**3/V
    Ia = Il - If
    I = Ia/A
    Atd = Z*I*thetam/360
    Atc = Z*I*(1/2*P - thetam/360)
    return print("Q-16 -->The distorion ampere turns per pole",Atd," AT/pole")
ques_16()


def ques_17():
    A =2
    Pw = 32.9 ##kw
    V = 320 ##V
    P =4  ##POLES
    Z = 600 ##conductors
    Comm = 105 ##commutator segments
    Eff = 0.858 ##not percent
    If = 3.9 ##A
    Sh = 3 ##segments
    thetam = 360/Comm * Sh
    Pin = Pw/Eff
    Il = Pin*10**3/V
    Ia = Il - If
    I = Ia/A
    Atd = Z*I*thetam/360
    Atc = Z*I*(1/2*P - thetam/360)
    return  print("Q-17 -->The distorion ampere turns per pole",Atd," AT/pole")
ques_17()


def ques_18():
        P = 6 ##pole
        Z = 650 ##conductors
        I= 180 ##A
        A=2
        and_dis = 3.95 ##angular degrees
        N = 1210
        ATd = Z*I/A*and_dis/360/N
        return print("Q-18 -->The additional current is ",ATd," A")
ques_18()


def ques_19():
  w1 = 5 ##kg
  w2 = 20 ##kg
  D=46 ##cm
  rpm=900 ##rpm
  V=210 ##v
  I=35 ##a
  R=D/2*10**-2
  pIN = V*I
  pout = 1.027*(w2-w1)*R*rpm
  Efficiency = pout/pIN*100
  return print("Q-19 -->the efficiency is ",Efficiency," %")

ques_19()

def ques_20():
    P1 =8 ## kW
    V =240 ##V
    Ra = 0.4 ##ohms
    Rf = 275 ##ohms
    If = 3.9 ##A
    Pin = 8 ##kW
    Ish = V/Rf
    Ia = If - Ish
    pin = V*If
    pcu = Ish**2 *  Rf + Ia**2 * Ra
    ploss = pin - pcu
    If= Pin*10**3/V
    Ia = If-Ish
    Pcu = Ish**2 *  Rf + Ia**2 * Ra
    Ploss = Pin*10**3 - Pcu - ploss
    Eff = Ploss/Pin/10**3*100
    return print("Q-20-->The Efficiency is ",Eff," %")
ques_20()
# Out:
# Q-11 -->The Total Rotational Loss of the machine is  962.5777777777777  W
# Q-12 -->The new rpm is  1230  rpm
# Q-13 -->The rpm is  1197.641629126835  rpm
# Q-14 -->The Current is  22.453131085962568  A
# Q-15 -->The RPM is  618.0336128005906  rpm
# Q-16 -->The distorion ampere turns per pole 500.7001432151808  AT/pole
# Q-17 -->The distorion ampere turns per pole 993.6693306693306  AT/pole
# Q-18 -->The additional current is  0.5304752066115702  A
# Q-19 -->the efficiency is  43.38551020408163  %
# Q-20-->The Efficiency is  83.07736717171717  %
